# %% [markdown]
# # Proyek Analisis Data: [Bike-sharing-dataset]
# - **Nama:** [Nabila Anggita Luna]
# - **Email:** [m296b4kx3180@bangkit.academy]
# - **ID Dicoding:** [Nabila_anggita_luna]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# pertanyaan 1: “Bagaimana performa pengguna jasa sewa sepeda tiap bulannya ?
#
# Pertanyaan 2:Bagaimana cuaca mempengaruhi kondisi perjalanan dan pengalaman pengguna saat bersepeda?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
#import necessary library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import calendar

# %% [markdown]
# **Insight:**
# - Disini saya mengimport beberapa library yang akan saya gunakan

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# membaca data yang telah saya simpan di github

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Nabilaanggita/dashboard_nabila/main/data/day.csv")

df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# file saya simpan di drive dan sudah saya buka aksesnya

# %% [markdown]
# ### Gathering Data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Nabilaanggita/dashboard_nabila/main/data/day.csv")

df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
h_df = pd.read_csv("https://raw.githubusercontent.com/Nabilaanggita/dashboard_nabila/refs/heads/main/data/hour.csv")

h_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Membaca melihat data yang telah disediakan

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# asessing data untuk data day

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# **Insight:**
# - Melihat tipe data

# %%
# Check for missing values
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
#check duplicate data
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Insight:**
# - check missing value dan duplicate data
# - sudah tidak terdapat missing value maupun diplicate data

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
df.dtypes
#cek type data
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# **Insight:**
# - tidak ada missing value pada data
# - tidak ada duplikasi data pada semua data
# - data sudah siap untuk digunakan

# %% [markdown]
# ### Cleaning Data

# %%
# Fungsi untuk mengonversi angka menjadi nama musim pada kolom season
def find_season(season):
    season_dict = {
        1: 'Winter',
        2: 'Spring',
        3: 'Summer',
        4: 'Fall'
    }
    return season_dict.get(season, "Unknown season")
df['season']= df['season'].apply(find_season)

print(df)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01  Winter   0     1        0        6           0
# 1          2  2011-01-02  Winter   0     1        0        0           0
# 2          3  2011-01-03  Winter   0     1        0        1           1
# 3          4  2011-01-04  Winter   0     1        0        2           1
# 4          5  2011-01-05  Winter   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27  Winter   1    12        0        4           1
# 727      728  2012-12-28  Winter   1    12        0        5           1
# 728      729  2012-12-29  Winter   1    12        0        6           0
# 729      730  2012-12-30  Winter   1    12        0        0           0
# 730      731  2012-12-31  Winter   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
# Fungsi untuk mengonversi angka menjadi nama weathersit pada kolom weathersit
def find_weathersit(weathersit):
    weathersit_dict = {
        1: 'Clear, Few clouds, Partly cloudy, Partly cloudy',
        2: 'Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist',
        3: 'Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered cloudsr',
        4: 'Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog'
    }
    return weathersit_dict.get(weathersit, "Unknown weathersit")
df['weathersit']= df['weathersit'].apply(find_weathersit)

print(df)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01  Winter   0     1        0        6           0
# 1          2  2011-01-02  Winter   0     1        0        0           0
# 2          3  2011-01-03  Winter   0     1        0        1           1
# 3          4  2011-01-04  Winter   0     1        0        2           1
# 4          5  2011-01-05  Winter   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27  Winter   1    12        0        4           1
# 727      728  2012-12-28  Winter   1    12        0        5           1
# 728      729  2012-12-29  Winter   1    12        0        6           0
# 729      730  2012-12-30  Winter   1    12        0        0           0
# 730      731  2012-12-31  Winter   1    12        0        1           1
#
#                                             weathersit      temp     atemp  \
# ...

# %%
# Fungsi untuk mengonversi angka menjadi huruf holiday non holiday
def find_holiday(holiday):
    holiday_dict = {
        0: 'non holiday',
        1: 'holiday'
    }
    return holiday_dict.get(holiday, "Unknown weathersit")
df['holiday']= df['holiday'].apply(find_holiday)

print(df)
# Out:
#      instant      dteday  season  yr  mnth      holiday  weekday  workingday  \
# 0          1  2011-01-01  Winter   0     1  non holiday        6           0
# 1          2  2011-01-02  Winter   0     1  non holiday        0           0
# 2          3  2011-01-03  Winter   0     1  non holiday        1           1
# 3          4  2011-01-04  Winter   0     1  non holiday        2           1
# 4          5  2011-01-05  Winter   0     1  non holiday        3           1
# ..       ...         ...     ...  ..   ...          ...      ...         ...
# 726      727  2012-12-27  Winter   1    12  non holiday        4           1
# 727      728  2012-12-28  Winter   1    12  non holiday        5           1
# 728      729  2012-12-29  Winter   1    12  non holiday        6           0
# 729      730  2012-12-30  Winter   1    12  non holiday        0           0
# 730      731  2012-12-31  Winter   1    12  non holiday        1           1
#
# ...

# %%
# fungsi untuk mengkonversi angka menjadi huruf pada tabel workingday
def find_workingday(workingday):
    workingday_dict = {
        0: 'non workingday',
        1: 'workingday'
    }
    return workingday_dict.get(workingday, "Unknown workingday")
df['workingday']= df['workingday'].apply(find_workingday)

print(df)
# Out:
#      instant      dteday  season  yr  mnth      holiday  weekday  \
# 0          1  2011-01-01  Winter   0     1  non holiday        6
# 1          2  2011-01-02  Winter   0     1  non holiday        0
# 2          3  2011-01-03  Winter   0     1  non holiday        1
# 3          4  2011-01-04  Winter   0     1  non holiday        2
# 4          5  2011-01-05  Winter   0     1  non holiday        3
# ..       ...         ...     ...  ..   ...          ...      ...
# 726      727  2012-12-27  Winter   1    12  non holiday        4
# 727      728  2012-12-28  Winter   1    12  non holiday        5
# 728      729  2012-12-29  Winter   1    12  non holiday        6
# 729      730  2012-12-30  Winter   1    12  non holiday        0
# 730      731  2012-12-31  Winter   1    12  non holiday        1
#
#          workingday                                         weathersit  \
# 0    non workingday  Mist + Cloudy, Mist + Broken clouds, Mist + Fe...
# ...

# %%
#menemukan dtaa weekday yang sesuai
df['dteday'] = pd.to_datetime(df['dteday'])

# %%
#mengubah wekkday menjadi data yang sesuai
df['weekday'] = df['dteday'].dt.day_name()

# %%
#mengganti bulan angka(integer) menjadi huruf nama bulannya (string)

df['mnth'] = df['dteday'].dt.month_name()

# %%
#mengubah yr menjadi tahun yang sesuai dengan dat dteday nya
df['yr'] = df['dteday'].dt.year

# %%
#melihat data setelah diubah sesuai ketentuan
df.head()
# Out:
#    instant     dteday  season    yr     mnth      holiday    weekday  \
# 0        1 2011-01-01  Winter  2011  January  non holiday   Saturday
# 1        2 2011-01-02  Winter  2011  January  non holiday     Sunday
# 2        3 2011-01-03  Winter  2011  January  non holiday     Monday
# 3        4 2011-01-04  Winter  2011  January  non holiday    Tuesday
# 4        5 2011-01-05  Winter  2011  January  non holiday  Wednesday
#
#        workingday                                         weathersit  \
# 0  non workingday  Mist + Cloudy, Mist + Broken clouds, Mist + Fe...
# 1  non workingday  Mist + Cloudy, Mist + Broken clouds, Mist + Fe...
# 2      workingday    Clear, Few clouds, Partly cloudy, Partly cloudy
# 3      workingday    Clear, Few clouds, Partly cloudy, Partly cloudy
# 4      workingday    Clear, Few clouds, Partly cloudy, Partly cloudy
#
#        temp     atemp       hum  windspeed  casual  registered   cnt
# ...

# %%
#melihat tipe data yang telah diubah

df.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                object
# yr                     int32
# mnth                  object
# holiday               object
# weekday               object
# workingday            object
# weathersit            object
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
#menyimpan dataset yang sudah diolah kedalam file baru
df.to_csv('data_siap.csv', index=False)

# %% [markdown]
# **Insight:**
# - pada tahap ini saya merubah beberapa tipe data yang masih berupa angka saya menginginkan data nya berubah menjadi data huruf yang sesuai dengan namanya
# - data yang sudah dirubah disimpan kembali bernama (data_siap.csv)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore data Day

# %%
df.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                object
# yr                     int32
# mnth                  object
# holiday               object
# weekday               object
# workingday            object
# weathersit            object
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
#bulan
df['mnth'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
#menampilkan tabel data month
df.groupby(by="mnth").agg({
          "mnth": "nunique",
          "cnt": ["mean", "std", "max", "min"]
})
# Out:
#              mnth          cnt
#           nunique         mean          std   max   min
# mnth
# April           1  4484.900000  1776.160778  7460   795
# August          1  5664.419355  1494.516146  7865  1115
# December        1  3403.806452  1549.639353  6606   441
# February        1  2655.298246  1145.313307  5062  1005
# January         1  2176.338710  1161.674370  4521   431
# July            1  5563.677419  1273.751871  8173  3285
# June            1  5772.366667  1240.400031  8120  3767
# March           1  3692.258065  1899.301812  8362   605
# May             1  5349.774194  1298.711561  8294  2633
# November        1  4247.183333  1285.712709  6852  1495
# October         1  5199.225806  1988.392517  8156    22
# September       1  5766.516667  1810.130649  8714  1842

# %%
#menampilkan data urut terbanyak berdasarkan bulan
df.groupby(by="mnth").nunique().sort_values(by='cnt', ascending=False)
# Out:
#            instant  dteday  season  yr  holiday  weekday  workingday  \
# mnth
# August          62      62       1   2        1        7           2
# December        62      62       2   2        2        7           2
# January         62      62       1   2        2        7           2
# July            62      62       1   2        2        7           2
# May             62      62       1   2        2        7           2
# October         62      62       1   2        2        7           2
# April           60      60       1   2        2        7           2
# June            60      60       2   2        1        7           2
# March           62      62       2   2        1        7           2
# November        60      60       1   2        2        7           2
# September       60      60       2   2        2        7           2
# February        57      57       1   2        2        7           2
#
# ...

# %%
#menampilkan data urut terkecil bulan
df.groupby(by="mnth").nunique().sort_values(by='cnt', ascending=True)
# Out:
#            instant  dteday  season  yr  holiday  weekday  workingday  \
# mnth
# February        57      57       1   2        2        7           2
# April           60      60       1   2        2        7           2
# June            60      60       2   2        1        7           2
# March           62      62       2   2        1        7           2
# November        60      60       1   2        2        7           2
# September       60      60       2   2        2        7           2
# August          62      62       1   2        1        7           2
# December        62      62       2   2        2        7           2
# January         62      62       1   2        2        7           2
# July            62      62       1   2        2        7           2
# May             62      62       1   2        2        7           2
# October         62      62       1   2        2        7           2
#
# ...

# %%
#menampilkan data urut terbanyak berdasarkan year
df.groupby(by="yr").nunique().sort_values(by='cnt', ascending=False)
# Out:
#       instant  dteday  season  mnth  holiday  weekday  workingday  weathersit  \
# yr
# 2012      366     366       4    12        2        7           2           3
# 2011      365     365       4    12        2        7           2           3
#
#       temp  atemp  hum  windspeed  casual  registered  cnt
# yr
# 2012   293    357  319        342     332         347  356
# 2011   294    353  332        349     328         347  352

# %%
#menampilkan data urut terbanyak berdasarkan weathersit
df.groupby(by="weathersit").nunique().sort_values(by='cnt', ascending=False)
# Out:
#                                                     instant  dteday  season  \
# weathersit
# Clear, Few clouds, Partly cloudy, Partly cloudy         463     463       4
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...      247     247       4
# Light Snow, Light Rain + Thunderstorm + Scatter...       21      21       4
#
#                                                     yr  mnth  holiday  \
# weathersit
# Clear, Few clouds, Partly cloudy, Partly cloudy      2    12        2
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...   2    12        2
# Light Snow, Light Rain + Thunderstorm + Scatter...   2     9        1
#
#                                                     weekday  workingday  temp  \
# weathersit
# Clear, Few clouds, Partly cloudy, Partly cloudy           7           2   357
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...        7           2   211
# Light Snow, Light Rain + Thunderstorm + Scatter...        6           2    21
#
# ...

# %%
#menampilkan data urut terkecil berdasarkan weathersit
df.groupby(by="weathersit").nunique().sort_values(by='cnt', ascending=True)
# Out:
#                                                     instant  dteday  season  \
# weathersit
# Light Snow, Light Rain + Thunderstorm + Scatter...       21      21       4
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...      247     247       4
# Clear, Few clouds, Partly cloudy, Partly cloudy         463     463       4
#
#                                                     yr  mnth  holiday  \
# weathersit
# Light Snow, Light Rain + Thunderstorm + Scatter...   2     9        1
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...   2    12        2
# Clear, Few clouds, Partly cloudy, Partly cloudy      2    12        2
#
#                                                     weekday  workingday  temp  \
# weathersit
# Light Snow, Light Rain + Thunderstorm + Scatter...        6           2    21
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...        7           2   211
# Clear, Few clouds, Partly cloudy, Partly cloudy           7           2   357
#
# ...

# %%
#menampilkan tabel data wethersit
df.groupby(by="weathersit").agg({
          "weathersit": "nunique",
          "cnt": ["mean", "std", "max", "min"]
})
# Out:
#                                                    weathersit          cnt  \
#                                                       nunique         mean
# weathersit
# Clear, Few clouds, Partly cloudy, Partly cloudy             1  4876.786177
# Light Snow, Light Rain + Thunderstorm + Scatter...          1  1803.285714
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...          1  4035.862348
#
#
#                                                             std   max  min
# weathersit
# Clear, Few clouds, Partly cloudy, Partly cloudy     1879.483989  8714  431
# Light Snow, Light Rain + Thunderstorm + Scatter...  1240.284449  4639   22
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...  1809.109918  8362  605

# %%
#mengekstrak 4 data berdasarkan musim [temp,atemp, hum, windsped]
float_vars = ['temp', 'atemp', 'hum', 'windspeed']
df_float = df[float_vars]
df_float.describe()
# Out:
#              temp       atemp         hum   windspeed
# count  731.000000  731.000000  731.000000  731.000000
# mean     0.495385    0.474354    0.627894    0.190486
# std      0.183051    0.162961    0.142429    0.077498
# min      0.059130    0.079070    0.000000    0.022392
# 25%      0.337083    0.337842    0.520000    0.134950
# 50%      0.498333    0.486733    0.626667    0.180975
# 75%      0.655417    0.608602    0.730209    0.233214
# max      0.861667    0.840896    0.972500    0.507463

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0, 0].hist(df_float['temp'], bins=10, color='skyblue', edgecolor='black')
axs[0, 0].set_title('Distribution of Temperature')
axs[0, 0].set_xlabel('Temperature')
axs[0, 0].set_ylabel('Frequency')

axs[0, 1].hist(df_float['atemp'], bins=10, color='lightgreen', edgecolor='black')
axs[0, 1].set_title('Distribution of Feeling Temperature')
axs[0, 1].set_xlabel('Feeling Temperature')
axs[0, 1].set_ylabel('Frequency')

axs[1, 0].hist(df_float['hum'], bins=10, color='salmon', edgecolor='black')
axs[1, 0].set_title('Distribution of Humidity')
axs[1, 0].set_xlabel('Humidity')
axs[1, 0].set_ylabel('Frequency')

axs[1, 1].hist(df_float['windspeed'], bins=10, color='gold', edgecolor='black')
axs[1, 1].set_title('Distribution of Windspeed')
axs[1, 1].set_xlabel('Windspeed')
axs[1, 1].set_ylabel('Frequency')


plt.tight_layout()  # Adjust spacing between subplots
plt.show()  # Display the plot

# %% [markdown]
# ###eksplor data hour

# %%
h_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
h_df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
h_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
h_df.groupby(by="weekday").agg({
    "weekday": "nunique",
    "cnt": ["max", "min", "mean", "std"]
})
# Out:
#         weekday  cnt
#         nunique  max min        mean         std
# weekday
# 0             1  776   1  177.468825  168.167710
# 1             1  968   1  183.744655  179.514167
# 2             1  970   1  191.238891  187.820480
# 3             1  977   1  191.130505  190.894464
# 4             1  976   1  196.436665  188.011923
# 5             1  957   1  196.135907  174.076894
# 6             1  783   1  190.209793  179.820569

# %%
h_df.groupby(by="holiday").agg({
    "holiday": "nunique",
    "cnt": ["max", "min", "mean", "std"]
})
# Out:
#         holiday  cnt
#         nunique  max min       mean         std
# holiday
# 0             1  977   1  190.42858  181.981435
# 1             1  712   1  156.87000  156.757478

# %%
h_df.groupby(by="workingday").agg({
    "workingday": "nunique",
    "cnt": ["max", "min", "mean", "std"]
})
# Out:
#            workingday  cnt
#               nunique  max min        mean         std
# workingday
# 0                   1  783   1  181.405332  172.853832
# 1                   1  977   1  193.207754  185.107477

# %%
h_df.groupby(by="weathersit").agg({
    "weathersit": "nunique",
    "cnt": ["max", "min", "mean", "std"]
})  #menampilkan data urut terbanyak berdasarkan weathersit
# Out:
#            weathersit  cnt
#               nunique  max min        mean         std
# weathersit
# 1                   1  977   1  204.869272  189.487773
# 2                   1  957   1  175.165493  165.431589
# 3                   1  891   1  111.579281  133.781045
# 4                   1  164  23   74.333333   77.925178

# %%
h_df.groupby(by="mnth").agg({
    "mnth": "nunique",
    "cnt": ["max", "min", "mean", "std"]
})  #menampilkan data urut terbanyak berdasarkan bulan
# Out:
#         mnth  cnt
#      nunique  max min        mean         std
# mnth
# 1          1  559   1   94.424773   99.907146
# 2          1  610   1  112.865026  112.486565
# 3          1  957   1  155.410726  163.543050
# 4          1  822   1  187.260960  181.137902
# 5          1  873   1  222.907258  187.721497
# 6          1  900   1  240.515278  196.038950
# 7          1  913   1  231.819892  187.483806
# 8          1  941   1  238.097627  200.444648
# 9          1  977   1  240.773138  214.609531
# 10         1  963   1  222.158511  203.477057
# 11         1  729   1  177.335421  158.973887
# 12         1  759   1  142.303439  141.080674

# %%
h_df.groupby(by="yr").agg({
    "yr": "nunique",
    "cnt": ["max", "min", "mean", "std"]
})  #menampilkan data urut terbanyak berdasarkan tahun
# Out:
#         yr  cnt
#    nunique  max min        mean         std
# yr
# 0        1  651   1  143.794448  133.797854
# 1        1  977   1  234.666361  208.910941

# %%
h_df.groupby(by="season").agg({
    "season": "nunique",
    "cnt": ["max", "min", "mean", "std"]
})  #menampilkan data urut terbanyak berdasarkan tahun
# Out:
#         season  cnt
#        nunique  max min        mean         std
# season
# 1            1  801   1  111.114569  119.224010
# 2            1  957   1  208.344069  188.362473
# 3            1  977   1  236.016237  197.711630
# 4            1  967   1  198.868856  182.967972

# %%
h_df.groupby(by="mnth").nunique().sort_values(by='cnt', ascending=False)
# Out:
#       instant  dteday  season  yr  hr  holiday  weekday  workingday  \
# mnth
# 8        1475      62       1   2  24        1        7           2
# 6        1440      60       2   2  24        1        7           2
# 9        1437      60       2   2  24        2        7           2
# 5        1488      62       1   2  24        2        7           2
# 7        1488      62       1   2  24        2        7           2
# 10       1451      62       1   2  24        2        7           2
# 4        1437      60       1   2  24        2        7           2
# 11       1437      60       1   2  24        2        7           2
# 3        1473      62       2   2  24        1        7           2
# 12       1483      62       2   2  24        2        7           2
# 2        1341      57       1   2  24        2        7           2
# 1        1429      62       1   2  24        2        7           2
#
#       weathersit  temp  atemp  hum  windspeed  casual  registered  cnt
# ...

# %%
h_df.groupby(by="yr").nunique().sort_values(by='cnt', ascending=False)
# Out:
#     instant  dteday  season  mnth  hr  holiday  weekday  workingday  \
# yr
# 1      8734     366       4    12  24        2        7           2
# 0      8645     365       4    12  24        2        7           2
#
#     weathersit  temp  atemp  hum  windspeed  casual  registered  cnt
# yr
# 1            4    50     61   81         26     319         772  866
# 0            4    48     65   88         29     229         514  585

# %%
h_df.groupby(by="workingday").nunique().sort_values(by='cnt', ascending=False)
# Out:
#             instant  dteday  season  yr  mnth  hr  holiday  weekday  \
# workingday
# 1             11865     500       4   2    12  24        1        5
# 0              5514     231       4   2    12  24        2        7
#
#             weathersit  temp  atemp  hum  windspeed  casual  registered  cnt
# workingday
# 1                    4    49     64   85         28     172         775  856
# 0                    4    49     61   83         28     322         444  676

# %%
h_df.groupby(by="holiday").nunique().sort_values(by='cnt', ascending=False)
# Out:
#          instant  dteday  season  yr  mnth  hr  weekday  workingday  \
# holiday
# 0          16879     710       4   2    12  24        7           2
# 1            500      21       4   2     9  24        5           1
#
#          weathersit  temp  atemp  hum  windspeed  casual  registered  cnt
# holiday
# 0                 4    50     65   89         30     322         776  869
# 1                 3    42     48   64         20     141         229  276

# %%
h_df.groupby(by="weathersit").nunique().sort_values(by='cnt', ascending=False)
# Out:
#             instant  dteday  season  yr  mnth  hr  holiday  weekday  \
# weathersit
# 1             11413     700       4   2    12  24        2        7
# 2              4544     567       4   2    12  24        2        7
# 3              1419     300       4   2    12  24        2        7
# 4                 3       3       1   2     1   3        1        3
#
#             workingday  temp  atemp  hum  windspeed  casual  registered  cnt
# weathersit
# 1                    2    50     65   84         28     315         744  848
# 2                    2    47     59   78         25     219         579  649
# 3                    2    40     49   57         25     121         327  368
# 4                    2     3      3    2          3       2           3    3

# %%
h_df.groupby(by="season").nunique().sort_values(by='cnt', ascending=False)
# Out:
#         instant  dteday  yr  mnth  hr  holiday  weekday  workingday  \
# season
# 3          4496     188   2     4  24        2        7           2
# 2          4409     184   2     4  24        2        7           2
# 4          4232     178   2     4  24        2        7           2
# 1          4242     181   2     4  24        2        7           2
#
#         weathersit  temp  atemp  hum  windspeed  casual  registered  cnt
# season
# 3                3    32     40   76         24     256         648  760
# 2                3    40     47   76         24     288         618  721
# 4                3    32     36   70         22     240         610  690
# 1                4    36     43   85         28     156         442  482

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# **pertanyaan:**
# -  “Bagaimana performa pengguna jasa sewa sepeda tiap bulannya ?

# %%
# tampilkan histogram tiap bulannya
plt.figure(figsize=(10,6))

sns.lineplot(x="dteday", y="cnt", data=df, color='blue')
plt.xlabel("Tanggal")
plt.ylabel("Total penyewa")
plt.title("grafik persewaan sepeda tiap bulannya pada tahun 2011-2012")
plt.tight_layout()
plt.show()

# %% [markdown]
# terlihat titik tertinggi untuk pernyewa adalah pada bulan 5 hingga 10 tahun 2012

# %%
#mengurutkan terbanyak perbulannya
df.sort_values(by=["mnth", "cnt"], ascending=[False, False])
# Out:
#      instant     dteday  season    yr       mnth      holiday   weekday  \
# 623      624 2012-09-15  Summer  2012  September  non holiday  Saturday
# 637      638 2012-09-29    Fall  2012  September  non holiday  Saturday
# 630      631 2012-09-22  Summer  2012  September  non holiday  Saturday
# 617      618 2012-09-09  Summer  2012  September  non holiday    Sunday
# 629      630 2012-09-21  Summer  2012  September  non holiday    Friday
# ..       ...        ...     ...   ...        ...          ...       ...
# 94        95 2011-04-05  Spring  2011      April  non holiday   Tuesday
# 111      112 2011-04-22  Spring  2011      April  non holiday    Friday
# 97        98 2011-04-08  Spring  2011      April  non holiday    Friday
# 477      478 2012-04-22  Spring  2012      April  non holiday    Sunday
# 105      106 2011-04-16  Spring  2011      April  non holiday  Saturday
#
#          workingday                                         weathersit  \
# ...

# %% [markdown]
# benar saja kita lihat pada saat kita urutkan data terbesar tabel nilai terbanyak penyewa adalah 8714 pada bulan oktober

# %%
#membuat tabel data bulan
mean_df = df.groupby(by="mnth").agg({
          "mnth": "nunique",
          "cnt": ["mean", "std", "max", "min"]
})
mean_df = mean_df.reset_index()
# memsisahkan menggunakan _
mean_df.columns = ["_".join(col) for col in mean_df.columns.values]

# %%
#diagram grafik rata rata mean max min pengguna sepeda tiap bulannya
plt.figure(figsize=(10,6))
sns.lineplot(x=mean_df.index, y=mean_df["cnt_mean"], color='blue')
sns.lineplot(x=mean_df.index, y=mean_df["cnt_std"], color='red')
sns.lineplot(x=mean_df.index, y=mean_df["cnt_max"], color='green')
sns.lineplot(x=mean_df.index, y=mean_df["cnt_min"], color='yellow')
plt.xlabel("bulan")
plt.ylabel("Total penyewa")
plt.title("rata grafik persewaan sepeda tiap bulannya pada tahun 2011-2012")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - analisis menggunakan rata rata pengguna tiap bulannya. pengguna naik turun pada saat bulan ke 4 terjadi penurunnan drastis. namun selanjutnya naik terjadi penurunan lagi namun tidak sedrastis pada bulan 4 dan terus meningkat.

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# **pertanyaan:**
# - Bagaimana cuaca mempengaruhi kondisi perjalanan dan pengalaman pengguna saat bersepeda?

# %%
#memperlihatkan data urut terbanyak penyewa berdasarkan weathersit
df.groupby(by="weathersit").nunique().sort_values(by='cnt', ascending=False)
# Out:
#                                                     instant  dteday  season  \
# weathersit
# Clear, Few clouds, Partly cloudy, Partly cloudy         463     463       4
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...      247     247       4
# Light Snow, Light Rain + Thunderstorm + Scatter...       21      21       4
#
#                                                     yr  mnth  holiday  \
# weathersit
# Clear, Few clouds, Partly cloudy, Partly cloudy      2    12        2
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...   2    12        2
# Light Snow, Light Rain + Thunderstorm + Scatter...   2     9        1
#
#                                                     weekday  workingday  temp  \
# weathersit
# Clear, Few clouds, Partly cloudy, Partly cloudy           7           2   357
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...        7           2   211
# Light Snow, Light Rain + Thunderstorm + Scatter...        6           2    21
#
# ...

# %% [markdown]
# pada saat weathersit bagus( Clear, Few clouds, Partly cloudy, Partly cloudy) memiliki banyak peminat sejumlah 451 orang

# %%
#memperlihatkan data urut tersedikit penyewa berdasarkan weathersit
df.groupby(by="weathersit").nunique().sort_values(by='cnt', ascending=True)
# Out:
#                                                     instant  dteday  season  \
# weathersit
# Light Snow, Light Rain + Thunderstorm + Scatter...       21      21       4
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...      247     247       4
# Clear, Few clouds, Partly cloudy, Partly cloudy         463     463       4
#
#                                                     yr  mnth  holiday  \
# weathersit
# Light Snow, Light Rain + Thunderstorm + Scatter...   2     9        1
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...   2    12        2
# Clear, Few clouds, Partly cloudy, Partly cloudy      2    12        2
#
#                                                     weekday  workingday  temp  \
# weathersit
# Light Snow, Light Rain + Thunderstorm + Scatter...        6           2    21
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...        7           2   211
# Clear, Few clouds, Partly cloudy, Partly cloudy           7           2   357
#
# ...

# %%
#diagram menampilkan data berdasarkan cuaca

plt.figure(figsize=(10,6))

sns.barplot(x="weathersit", y="cnt", data=df)

plt.xlabel("weathersit")
plt.ylabel("Total pesepeda")
plt.title("hitung Pesepeda berdasarkan cuaca")

plt.xticks(rotation=15, ha='right')

plt.tight_layout()  # Adjust spacing to prevent labels from being cut off
plt.show()

# %%
seasonly_users_df = df.groupby("weathersit").agg({
    "casual": "sum",
    "registered": "sum",
    "cnt": "sum"
})

seasonly_users_df.head()
# Out:
#                                                     casual  registered  \
# weathersit
# Clear, Few clouds, Partly cloudy, Partly cloudy     446346     1811606
# Light Snow, Light Rain + Thunderstorm + Scatter...    3895       33974
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...  169776      827082
#
#                                                         cnt
# weathersit
# Clear, Few clouds, Partly cloudy, Partly cloudy     2257952
# Light Snow, Light Rain + Thunderstorm + Scatter...    37869
# Mist + Cloudy, Mist + Broken clouds, Mist + Few...   996858

# %% [markdown]
# **Insight:**
# - data menunjukan ketika weathersit buruk (Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered cloudsr) sangat sedikit peminat.

# %% [markdown]
# kita kaitkan kedua data tersebut

# %%
#mengurutkan terbanyak perharinya
df.sort_values(by=["mnth", "cnt"], ascending=[False, False])
# Out:
#      instant     dteday  season    yr       mnth      holiday   weekday  \
# 623      624 2012-09-15  Summer  2012  September  non holiday  Saturday
# 637      638 2012-09-29    Fall  2012  September  non holiday  Saturday
# 630      631 2012-09-22  Summer  2012  September  non holiday  Saturday
# 617      618 2012-09-09  Summer  2012  September  non holiday    Sunday
# 629      630 2012-09-21  Summer  2012  September  non holiday    Friday
# ..       ...        ...     ...   ...        ...          ...       ...
# 94        95 2011-04-05  Spring  2011      April  non holiday   Tuesday
# 111      112 2011-04-22  Spring  2011      April  non holiday    Friday
# 97        98 2011-04-08  Spring  2011      April  non holiday    Friday
# 477      478 2012-04-22  Spring  2012      April  non holiday    Sunday
# 105      106 2011-04-16  Spring  2011      April  non holiday  Saturday
#
#          workingday                                         weathersit  \
# ...

# %% [markdown]
# pada bulan peminat tertinggi tersebut juga menunjukkan 5 data teratas pada saat weathersit (Clear, Few clouds, Partly cloudy, Partly cloudy)
#
# hal ini bisa di simpulkan bahwa weathersit sangat mempengaruhi jumlah pengguna sepeda.

# %% [markdown]
# Selanjutnya kita lihat ketika penurunan peminat pengguna sepeda pada bulan tertentu terjadi.

# %%
#mengurutkan data bersarkan bulan peminat 10 data terendah
df.sort_values(by=["mnth", "cnt"], ascending=[True, True]).head(10)
# Out:
#      instant     dteday  season    yr   mnth      holiday    weekday  \
# 105      106 2011-04-16  Spring  2011  April  non holiday   Saturday
# 477      478 2012-04-22  Spring  2012  April  non holiday     Sunday
# 97        98 2011-04-08  Spring  2011  April  non holiday     Friday
# 111      112 2011-04-22  Spring  2011  April  non holiday     Friday
# 94        95 2011-04-05  Spring  2011  April  non holiday    Tuesday
# 101      102 2011-04-12  Spring  2011  April  non holiday    Tuesday
# 102      103 2011-04-13  Spring  2011  April  non holiday  Wednesday
# 90        91 2011-04-01  Spring  2011  April  non holiday     Friday
# 91        92 2011-04-02  Spring  2011  April  non holiday   Saturday
# 98        99 2011-04-09  Spring  2011  April  non holiday   Saturday
#
#          workingday                                         weathersit  \
# 105  non workingday  Light Snow, Light Rain + Thunderstorm + Scatte...
# ...

# %% [markdown]
# terlihat pada bulan april memiliki peminat sedikit karena cuaca yang buruk

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclusion pertanyaan 1: peforma tiap bulan pengguna naik turun namun cenderung meningkat .
# grafik tiap bulannya mengalami naik turun.terjadi penurunan yang sangat drastis pda bulan april. setelah saya analisis lebih lanjut dikarenakan faktor cuaca. kemudian pda saat bulan berikutnya meningkat terjadi penurunan namun tidak sedrastis pada bulan pertama.
#
# - Conclusion pertanyaan 2 : cuaca sangat berpengaaruh terhadap peminat pengguna sepeda
#
#  Ketika cuaca sangat buruk, hanya ada sedikit peminat pengguna sepeda. Ini mungkin karena mereka tidak ingin mengambil risiko terjadi sesuatu yang buruk. ini hal wajar bahwa penurunan permintaan selama cuaca buruk dan cuaca adalah faktor eksternal yang mungkin kita tidak bisa atur. Menggunakan sepeda saat cuaca buruk dapat meningkatkan risiko kecelakaan atau kerusakan pada sepeda.
